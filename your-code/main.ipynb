# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# Import reduce from functools, numpy and pandas
from functools import reduce
import numpy
import pandas

# %% [markdown]
# # Challenge 1 - Mapping
#
# #### We will use the map function to clean up words in a book.
#
# In the following cell, we will read a text file containing the book The Prophet by Khalil Gibran.

# %%
# Run this code:

location = '../data/58585-0.txt'
with open(location, 'r', encoding="utf8") as f:
    prophet = f.read().split(' ')

# %%
len(prophet)
# Out:
# 13637

# %% [markdown]
# #### Let's remove the first 568 words since they contain information about the book but are not part of the book itself.
# Do this by removing from prophet elements 0 through 567 of the list (you can also do this by keeping elements 568 through the last element).

# %%
# your code here
prophet = prophet[568:]
print(prophet)
# Out:
# ['PROPHET\n\n|Almustafa,', 'the{7}', 'chosen', 'and', 'the\nbeloved,', 'who', 'was', 'a', 'dawn', 'unto', 'his', 'own\nday,', 'had', 'waited', 'twelve', 'years', 'in', 'the', 'city\nof', 'Orphalese', 'for', 'his', 'ship', 'that', 'was', 'to\nreturn', 'and', 'bear', 'him', 'back', 'to', 'the', 'isle', 'of\nhis', 'birth.\n\nAnd', 'in', 'the', 'twelfth', 'year,', 'on', 'the', 'seventh\nday', 'of', 'Ielool,', 'the', 'month', 'of', 'reaping,', 'he\nclimbed', 'the', 'hill', 'without', 'the', 'city', 'walls\nand', 'looked', 'seaward;', 'and', 'he', 'beheld', 'his\nship', 'coming', 'with', 'the', 'mist.\n\nThen', 'the', 'gates', 'of', 'his', 'heart', 'were', 'flung\nopen,', 'and', 'his', 'joy', 'flew', 'far', 'over', 'the', 'sea.\nAnd', 'he', 'closed', 'his', 'eyes', 'and', 'prayed', 'in', 'the\nsilences', 'of', 'his', 'soul.\n\n*****\n\nBut', 'as', 'he', 'descended', 'the', 'hill,', 'a', 'sadness\ncame', 'upon', 'him,', 'and', 'he', 'thought', 'in', 'his\nheart:\n\nHow', 'shall', 'I', 'go', 'in', 'peace', 'and', 'without\nsorrow?', 'Nay,', 'not', 'without', 'a', 'wound', 'in', 'the\nspirit', 'shall', 'I', 'leave', 'this', 'city.', '{8}Long\nwere', 'the', 'days', 'of', 'pain', 'I', 'have', 'spent\nwithin', 'its', 'walls,', 'and', 'long', 'were', 'the\nnights', 'of', 'aloneness;', 'and', 'who', 'can', 'depart\nfrom', 'his', 'pain', 'and', 'his', 'aloneness', 'without\nregret?\n\nToo', 'many', 'fragments', 'of', 'the', 'spirit', 'have', 'I\nscattered', 'in', 'these', 'streets,', 'and', 'too', 'many\nare', 'the', 'children', 'of', 'my', 'longing', 'that', 'walk\nnaked', 'among', 'these', 'hills,', 'and', 'I', 'cannot\nwithdraw', 'from', 'them', 'without', 'a', 'burden', 'and\nan', 'ache.\n\nIt', 'is', 'not', 'a', 'garment', 'I', 'cast', 'off', 'this\nday,', 'but', 'a', 'skin', 'that', 'I', 'tear', 'with', 'my', 'own\nhands.\n\nNor', 'is', 'it', 'a', 'thought', 'I', 'leave', 'behind', 'me,\nbut', 'a', 'heart', 'made', 'sweet', 'with', 'hunger', 'and\nwith', 'thirst.\n\n*****\n\nYet', 'I', 'cannot', 'tarry', 'longer.\n\nThe', 'sea', 'that', 'calls', 'all', 'things', 'unto', 'her\ncalls', 'me,', 'and', 'I', 'must', 'embark.\n\nFor', 'to', 'stay,', 'though', 'the', 'hours', 'burn', 'in\nthe', 'night,', 'is', 'to', 'freeze', 'and', 'crystallize\nand', 'be', 'bound', 'in', 'a', 'mould.\n\nFain', 'would', 'I', 'take', 'with', 'me', 'all', 'that', 'is\nhere.', 'But', 'how', 'shall', 'I?\n\nA', 'voice', 'cannot', 'carry', 'the', 'tongue', 'and\n{9}the', 'lips', 'that', 'gave', 'it', 'wings.', 'Alone\nmust', 'it', 'seek', 'the', 'ether.\n\nAnd', 'alone', 'and', 'without', 'his', 'nest', 'shall', 'the\neagle', 'fly', 'across', 'the', 'sun.\n\n*****\n\nNow', 'when', 'he', 'reached', 'the', 'foot', 'of', 'the\nhill,', 'he', 'turned', 'again', 'towards', 'the', 'sea,\nand', 'he', 'saw', 'his', 'ship', 'approaching', 'the\nharbour,', 'and', 'upon', 'her', 'prow', 'the', 'mariners,\nthe', 'men', 'of', 'his', 'own', 'land.\n\nAnd', 'his', 'soul', 'cried', 'out', 'to', 'them,', 'and', 'he\nsaid:\n\nSons', 'of', 'my', 'ancient', 'mother,', 'you', 'riders', 'of\nthe', 'tides,\n\nHow', 'often', 'have', 'you', 'sailed', 'in', 'my', 'dreams.\nAnd', 'now', 'you', 'come', 'in', 'my', 'awakening,', 'which\nis', 'my', 'deeper', 'dream.\n\nReady', 'am', 'I', 'to', 'go,', 'and', 'my', 'eagerness', 'with\nsails', 'full', 'set', 'awaits', 'the', 'wind.\n\nOnly', 'another', 'breath', 'will', 'I', 'breathe', 'in\nthis', 'still', 'air,', 'only', 'another', 'loving', 'look\ncast', 'backward,\n\nAnd', 'then', 'I', 'shall', 'stand', 'among', 'you,', 'a\nseafarer', 'among', 'seafarers.', '{10}And', 'you,\nvast', 'sea,', 'sleepless', 'mother,\n\nWho', 'alone', 'are', 'peace', 'and', 'freedom', 'to', 'the\nriver', 'and', 'the', 'stream,\n\nOnly', 'another', 'winding', 'will', 'this', 'stream\nmake,', 'only', 'another', 'murmur', 'in', 'this', 'glade,\n\nAnd', 'then', 'shall', 'I', 'come', 'to', 'you,', 'a\nboundless', 'drop', 'to', 'a', 'boundless', 'ocean.\n\n*****\n\nAnd', ' ...

# %% [markdown]
# If you look through the words, you will find that many words have a reference attached to them. For example, let's look at words 1 through 10.

# %%
# your code here
print(prophet[:10])
# Out:
# ['PROPHET\n\n|Almustafa,', 'the{7}', 'chosen', 'and', 'the\nbeloved,', 'who', 'was', 'a', 'dawn', 'unto']

# %% [markdown]
# #### The next step is to create a function that will remove references.
#
# We will do this by splitting the string on the `{` character and keeping only the part before this character. Write your function below.

# %%
def reference(x):
    '''
    Input: A string
    Output: The string with references removed
    
    Example:
    Input: 'the{7}'
    Output: 'the'
    '''
    '''
    if '{' in x:
        index_ = x.index('{')
        return x[:index_]
    return x
    '''
    return x.split('{')[0]
    
    # your code here

# %%
# your code here
prophet_reference = list(map(reference, prophet))
print(prophet_reference[:10])
# Out:
# ['PROPHET\n\n|Almustafa,', 'the', 'chosen', 'and', 'the\nbeloved,', 'who', 'was', 'a', 'dawn', 'unto']

# %% [markdown]
# Now that we have our function, use the `map()` function to apply this function to our book, The Prophet. Return the resulting list to a new list called `prophet_reference`.

# %%
# your code here

# %% [markdown]
# Another thing you may have noticed is that some words contain a line break. Let's write a function to split those words. Our function will return the string split on the character `\n`. Write your function in the cell below.

# %%
def line_break(x):
    '''
    Input: A string
    Output: A list of strings split on the line break (\n) character
        
    Example:
    Input: 'the\nbeloved'
    Output: ['the', 'beloved']
    '''
    output_list = []
    while "\n" in x:
        index = x.index('\n')
        output_list.append(x[:index])
        x = x[index+2:]        
        
    output_list.append(x)
    return output_list
    # your code here

# %% [markdown]
# Apply the `line_break` function to the `prophet_reference` list. Name the new list `prophet_line`.

# %%
# your code here
prophet_line = list(map(line_break, prophet_reference))

prophet_line
# Out:
# [['PROPHET', '|Almustafa,'],
#  ['the'],
#  ['chosen'],
#  ['and'],
#  ['the', 'eloved,'],
#  ['who'],
#  ['was'],
#  ['a'],
#  ['dawn'],
#  ['unto'],
#  ['his'],
#  ['own', 'ay,'],
#  ['had'],
#  ['waited'],
#  ['twelve'],
#  ['years'],
#  ['in'],
#  ['the'],
#  ['city', 'f'],
#  ['Orphalese'],
#  ['for'],
#  ['his'],
#  ['ship'],
#  ['that'],
#  ['was'],
#  ['to', 'eturn'],
#  ['and'],
#  ['bear'],
#  ['him'],
#  ['back'],
#  ['to'],
#  ['the'],
#  ['isle'],
#  ['of', 'is'],
#  ['birth.', 'And'],
#  ['in'],
#  ['the'],
#  ['twelfth'],
#  ['year,'],
#  ['on'],
#  ['the'],
#  ['seventh', 'ay'],
#  ['of'],
#  ['Ielool,'],
#  ['the'],
#  ['month'],
#  ['of'],
#  ['reaping,'],
#  ['he', 'limbed'],
#  ['the'],
#  ['hill'],
#  ['without'],
#  ['the'],
#  ['city'],
#  ['walls', 'nd'],
#  ['looked'],
#  ['seaward;'],
#  ['and'],
#  ['he'],
#  ['beheld'],
#  ['his', 'hip'],
#  ['coming'],
#  ['with'],
#  ['the'],
#  ['mist.', 'Then'],
#  ['the'],
#  ['gates'],
#  ['of'],
#  ['his'],
#  ['heart'],
#  ['were'],
#  ['flung', 'pen,'],
#  ['and'],
#  ['his'],
#  ['joy'],
#  ['flew'],
#  ['far'],
#  ['over'],
#  ['the'],
#  ['sea.', 'nd'],
#  ['he'],
#  ['closed'],
#  ['his'],
#  ['eyes'],
#  ['and'],
#  ['prayed'],
#  ['in'],
#  ['the', 'ilences'],
#  ['of'],
#  ['his'],
#  ['soul.', '*****', 'But'],
#  ['as'],
#  ['he'],
#  ['descended'],
#  ['the'],
#  ['hill,'],
#  ['a'],
#  ['sadness', 'ame'],
#  ['upon'],
#  ['him,'],
#  ['and'],
#  ['he'],
#  ['thought'],
#  ['in'],
#  ['his', 'eart:', 'How'],
#  ['shall'],
#  ['I'],
#  ['go'],
#  ['in'],
#  ['peace'],
#  ['and'],
#  ['without', 'orrow?'],
#  ['Nay,'],
#  ['not'],
#  ['without'],
#  ['a'],
#  ['wound'],
#  ['in'],
#  ['the', 'pirit'],
#  ['shall'],
#  ['I'],
#  ['leave'],
#  ['this'],
#  ['city.'],
#  [''],
#  ['the'],
#  ['days'],
#  ['of'],
#  ['pain'],
#  ['I'],
#  ['have'],
#  ['spent', 'ithin'],
#  ['its'],
#  ['walls,'],
#  ['and'],
#  ['long'],
#  ['were'],
#  ['the', 'ights'],
#  ['of'],
#  ['aloneness;'],
#  ['and'],
#  ['who'],
#  ['can'],
#  ['depart', 'rom'],
#  ['his'],
#  ['pain'],
#  ['and'],
#  ['his'],
#  ['aloneness'],
#  ['without', 'egret?', 'Too'],
#  ['many'],
#  ['fragments'],
#  ['of'],
#  ['the'],
#  ['spirit'],
#  ['have'],
#  ['I', 'cattered'],
#  ['in'],
#  ['these'],
#  ['streets,'],
#  ['and'],
#  ['too'],
#  ['many', 're'],
#  ['the'],
#  ['children'],
#  ['of'],
#  ['my'],
#  ['longing'],
#  ['that'],
#  ['walk', 'aked'],
#  ['among'],
#  ['these'],
#  ['hills,'],
#  ['and'],
#  ['I'],
#  ['cannot', 'ithdraw'],
#  ['from'],
#  ['them'],
#  ['without'],
#  ['a'],
#  ['burden'],
#  ['and', 'n'],
#  ['ache.', 'It'],
#  ['is'],
#  ['not'],
#  ['a'],
#  ['garment'],
#  ['I'],
#  ['cast'],
#  ['off'],
#  ['this', 'ay,'],
#  ['but'],
#  ['a'],
#  ['skin'],
#  ['that'],
#  ['I'],
#  ['tear'],
#  ['with'],
#  ['my'],
#  ['own', 'ands.', 'Nor'],
#  ['is'],
#  ['it'],
#  ['a'],
#  ['thought'],
#  ['I'],
#  ['leave'],
#  ['behind'],
#  ['me,', 'ut'],
#  ['a'],
#  ['heart'],
#  ['made'],
#  ['sweet'],
#  ['with'],
#  ['hunger'],
#  ['and', 'ith'],
#  ['thirst.', '*****', 'Yet'],
#  ['I'],
#  ['cannot'],
#  ['tarry'],
#  ['longer.', 'The'],
#  ['sea'],
#  ['that'],
#  ['calls'],
#  ['all'],
#  ['things'],
#  ['unto'],
#  ['her', 'alls'],
#  ['me,'],
#  ['and'],
#  ['I'],
#  ['must'],
#  ['embark.', 'For'],
#  ['to'],
#  ['stay,'],
#  ['though'],
#  ['the'],
#  ['hours'],
#  ['burn'],
#  ['in', 'he'],
#  ['night,'],
#  ['is'],
#  ['to'],
#  ['freeze'],
#  ['and'],
#  ['crystallize', 'nd'],
#  ['be'],
#  ['bound'],
#  ['in'],
#  ['a'],
#  ['mould.', 'Fain'],
#  ['would'],
#  ['I'],
#  ['take'],
#  ['with'],
#  ['me'],
#  ['all'],
#  ['that'],
#  ['is', 'ere.'],
#  ['But'],
#  ['how'],
#  ['shall'],
#  ['I?', 'A'],
#  ['voice'],
#  ['cannot'],
#  ['carry'],
#  ['the'],
#  ['tongue'],
#  ['and', ''],
#  ['lips'],
#  ['that'],
#  ['gave'],
#  ['it'],
#  ['wings.'],
#  ['Alone', 'ust'],
#  ['it'],
#  ['seek'],
#  ['the'],
#  ['ether.', 'And'],
#  ['alone'],
#  ['and'],
#  ['without'],
#  ['his'],
#  ['nest'],
#  ['shall'],
#  ['the', 'agle'],
#  ['fly'],
#  ['across'],
#  ['the'],
#  ['sun.', '*****', 'Now'],
#  ['when'],
#  ['he'],
#  ['reached'],
#  ['the'],
#  ['foot'],
#  ['of'],
#  ['the', 'ill,'],
#  ['he'],
#  ['turned'],
#  ['again'],
#  ['towards'],
#  ['the'],
#  ['sea,', 'nd'],
#  ['he'],
#  ['saw'],
#  ['his'],
#  ['ship'],
#  ['approaching'],
#  ['the', 'arbour,'],
#  ['and'],
#  ['upon'],
#  ['her'],
#  ['prow'],
#  ['the'],
#  ['mariners,', 'he'],
#  ['men'],
#  ['of'],
#  ['his'],
#  ['own'],
#  ['land.', 'And'],
#  ['his'],
#  ['soul'],
#  ['cried'],
#  ['out'],
#  ['to'],
#  ['them,'],
#  ['and'],
#  ['he', 'aid:', 'Sons'],
#  ['of'],
#  ['my'],
#  ['ancient'],
#  ['mother,'],
#  ['you'],
#  ['riders'],
#  ['of', 'he'],
#  ['tides,', 'How'],
#  ['often'],
#  ['have'],
#  ['you'],
#  ['sailed'],
#  ['in'],
#  ['my'],
#  ['dreams.', 'nd'],
#  ['now'],
#  ['you'],
#  ['come'],
#  ['in'],
#  ['my'],
#  ['awakening,'],
#  ['which', 's'],
#  ['my'],
#  ['deeper'],
#  ['dream.', 'Ready'],
#  ['am'],
#  ['I'],
#  ['to'],
#  ['go,'],
#  ['and'],
#  ['my'],
#  ['eagerness'],
#  ['with', 'ails'],
#  ['full'],
#  ['set'],
#  ['awaits'],
#  ['the'],
#  ['wind.', 'Only'],
#  ['another'],
#  ['breath'],
#  ['will'],
#  ['I'],
#  ['breathe'],
#  ['in', 'his'],
#  ['still'],
#  ['air,'],
#  ['only'],
#  ['another'],
#  ['loving'],
#  ['look', 'ast'],
#  ['backward,', 'And'],
#  ['then'],
#  ['I'],
#  ['shall'],
#  ['stand'],
#  ['among'],
#  ['you,'],
#  ['a', 'eafarer'],
#  ['among'],
#  ['seafarers.'],
#  [''],
#  ['you,', 'ast'],
#  ['sea,'],
#  ['sleepless'],
#  ['mother,', 'Who'],
#  ['alone'],
#  ['are'],
#  ['peace'],
#  ['and'],
#  ['freedom'],
#  ['to'],
#  ['the', 'iver'],
#  ['and'],
#  ['the'],
#  ['stream,', 'Only'],
#  ['another'],
#  ['winding'],
#  ['will'],
#  ['this'],
#  ['stream', 'ake,'],
#  ['only'],
#  ['another'],
#  ['murmur'],
#  ['in'],
#  ['this'],
#  ['glade,', 'And'],
#  ['then'],
#  ['shall'],
#  ['I'],
#  ['come'],
#  ['to'],
#  ['you,'],
#  ['a', 'oundless'],
#  ['drop'],
#  ['to'],
#  ['a'],
#  ['boundless'],
#  ['ocean.', '*****', 'And'],
#  ['as'],
#  ['he'],
#  ['walked'],
#  ['he'],
#  ['saw'],
#  ['from'],
#  ['afar'],
#  ['men', 'nd'],
#  ['women'],
#  ['leaving'],
#  ['their'],
#  ['fields'],
#  ['and'],
#  ['their', 'ineyards'],
#  ['and'],
#  ['hastening'],
#  ['towards'],
#  ['the'],
#  ['city', 'ates.', 'And'],
#  ['he'],
#  ['heard'],
#  ['their'],
#  ['voices'],
#  ['calling'],
#  ['his', 'ame,'],
#  ['and'],
#  ['shouting'],
#  ['from'],
#  ['field'],
#  ['to'],
#  ['field', 'elling'],
#  ['one'],
#  ['another'],
#  ['of'],
#  ['the'],
#  ['coming'],
#  ['of'],
#  ['his', 'hip.', 'And'],
#  ['he'],
#  ['said'],
#  ['to'],
#  ['himself:', 'Shall'],
#  ['the'],
#  ['day'],
#  ['of'],
#  ['parting'],
#  ['be'],
#  ['the'],
#  ['day'],
#  ['of', 'athering?', 'And'],
#  ['shall'],
#  ['it'],
#  ['be'],
#  ['said'],
#  ['that'],
#  ['my'],
#  ['eve'],
#  ['was'],
#  ['in', 'ruth'],
#  ['my'],
#  ['dawn?', 'And'],
#  ['what'],
#  ['shall'],
#  ['I'],
#  ['give'],
#  ['unto'],
#  ['him'],
#  ['who'],
#  ['has', 'eft'],
#  ['his'],
#  ['plough'],
#  ['in'],
#  ['midfurrow,'],
#  ['or'],
#  ['to', 'im'],
#  ['who'],
#  ['has'],
#  ['stopped'],
#  ['the'],
#  ['wheel'],
#  ['of'],
#  ['his', 'inepress?'],
#  [''],
#  ['my'],
#  ['heart'],
#  ['become'],
#  ['a', 'ree'],
#  ['heavy-laden'],
#  ['with'],
#  ['fruit'],
#  ['that'],
#  ['I'],
#  ['may', 'ather'],
#  ['and'],
#  ['give'],
#  ['unto'],
#  ['them?', 'And'],
#  ['shall'],
#  ['my'],
#  ['desires'],
#  ['flow'],
#  ['like'],
#  ['a', 'ountain'],
#  ['that'],
#  ['I'],
#  ['may'],
#  ['fill'],
#  ['their'],
#  ['cups?', 'Am'],
#  ['I'],
#  ['a'],
#  ['harp'],
#  ['that'],
#  ['the'],
#  ['hand'],
#  ['of'],
#  ['the'],
#  ['mighty', 'ay'],
#  ['touch'],
#  ['me,'],
#  ['or'],
#  ['a'],
#  ['flute'],
#  ['that'],
#  ['his'],
#  ['breath', 'ay'],
#  ['pass'],
#  ['through'],
#  ['me?', 'A'],
#  ['seeker'],
#  ['of'],
#  ['silences'],
#  ['am'],
#  ['I,'],
#  ['and'],
#  ['what', 'reasure'],
#  ['have'],
#  ['I'],
#  ['found'],
#  ['in'],
#  ['silences'],
#  ['that'],
#  ['I', 'ay'],
#  ['dispense'],
#  ['with'],
#  ['confidence?', 'If'],
#  ['this'],
#  ['is'],
#  ['my'],
#  ['day'],
#  ['of'],
#  ['harvest,'],
#  ['in'],
#  ['what', 'ields'],
#  ['have'],
#  ['I'],
#  ['sowed'],
#  ['the'],
#  ['seed,'],
#  ['and'],
#  ['in', 'hat'],
#  ['unremembered'],
#  ['seasons?', 'If'],
#  ['this'],
#  ['indeed'],
#  ['be'],
#  ['the'],
#  ['hour'],
#  ['in'],
#  ['which'],
#  ['I', 'ift'],
#  ['up'],
#  ['my'],
#  ['lantern,'],
#  ['it'],
#  ['is'],
#  ['not'],
#  ['my'],
#  ['flame', 'hat'],
#  ['shall'],
#  ['burn'],
#  ['therein.', 'Empty'],
#  ['and'],
#  ['dark'],
#  ['shall'],
#  ['I'],
#  ['raise'],
#  ['my'],
#  ['lantern,', 'And'],
#  ['the'],
#  ['guardian'],
#  ['of'],
#  ['the'],
#  ['night'],
#  ['shall'],
#  ['fill', 't'],
#  ['with'],
#  ['oil'],
#  ['and'],
#  ['he'],
#  ['shall'],
#  ['light'],
#  ['it'],
#  ['also.', '*****', 'These'],
#  ['things'],
#  ['he'],
#  ['said'],
#  ['in'],
#  ['words.'],
#  ['But'],
#  ['much', 'n'],
#  ['his'],
#  ['heart'],
#  ['remained'],
#  ['unsaid.'],
#  ['For'],
#  [''],
#  ['could'],
#  ['not'],
#  ['speak'],
#  ['his'],
#  ['deeper', 'ecret.', '*****', '[Illustration:'],
#  ['0020]', 'And'],
#  ['when'],
#  ['he'],
#  ['entered'],
#  ['into'],
#  ['the'],
#  ['city'],
#  ['all', 'he'],
#  ['people'],
#  ['came'],
#  ['to'],
#  ['meet'],
#  ['him,'],
#  ['and'],
#  ['they', 'ere'],
#  ['crying'],
#  ['out'],
#  ['to'],
#  ['him'],
#  ['as'],
#  ['with'],
#  ['one', 'oice.', 'And'],
#  ['the'],
#  ['elders'],
#  ['of'],
#  ['the'],
#  ['city'],
#  ['stood'],
#  ['forth', 'nd'],
#  ['said:', 'Go'],
#  ['not'],
#  ['yet'],
#  ['away'],
#  ['from'],
#  ['us.', 'A'],
#  ['noontide'],
#  ['have'],
#  ['you'],
#  ['been'],
#  ['in'],
#  ['our', 'wilight,'],
#  ['and'],
#  ['your'],
#  ['youth'],
#  ['has'],
#  ['given'],
#  ['us', 'reams'],
#  ['to'],
#  ['dream.', 'No'],
#  ['stranger'],
#  ['are'],
#  ['you'],
#  ['among'],
#  ['us,'],
#  ['nor', ''],
#  ['guest,'],
#  ['but'],
#  ['our'],
#  ['son'],
#  ['and'],
#  ['our'],
#  ['dearly', 'eloved.', 'Suffer'],
#  ['not'],
#  ['yet'],
#  ['our'],
#  ['eyes'],
#  ['to'],
#  ['hunger'],
#  ['for', 'our'],
#  ['face.', '*****', 'And'],
#  ['the'],
#  ['priests'],
#  ['and'],
#  ['the'],
#  ['priestesses'],
#  ['said', 'nto'],
#  ['him:', 'Let'],
#  ['not'],
#  ['the'],
#  ['waves'],
#  ['of'],
#  ['the'],
#  ['sea'],
#  ['separate'],
#  ['us', 'ow,'],
#  ['and'],
#  ['the'],
#  ['years'],
#  ['you'],
#  ['have'],
#  ['spent'],
#  ['in'],
#  ['our', 'idst'],
#  ['become'],
#  ['a'],
#  ['memory.', 'You'],
#  ['have'],
#  ['walked'],
#  ['among'],
#  ['us'],
#  ['a'],
#  ['spirit,', ''],
#  ['your'],
#  ['shadow'],
#  ['has'],
#  ['been'],
#  ['a'],
#  ['light', 'pon'],
#  ['our'],
#  ['faces.', 'Much'],
#  ['have'],
#  ['we'],
#  ['loved'],
#  ['you.'],
#  ['But'],
#  ['speechless', 'as'],
#  ['our'],
#  ['love,'],
#  ['and'],
#  ['with'],
#  ['veils'],
#  ['has'],
#  ['it'],
#  ['been', 'eiled.', 'Yet'],
#  ['now'],
#  ['it'],
#  ['cries'],
#  ['aloud'],
#  ['unto'],
#  ['you,'],
#  ['and', 'ould'],
#  ['stand'],
#  ['revealed'],
#  ['before'],
#  ['you.', 'And'],
#  ['ever'],
#  ['has'],
#  ['it'],
#  ['been'],
#  ['that'],
#  ['love'],
#  ['knows', 'ot'],
#  ['its'],
#  ['own'],
#  ['depth'],
#  ['until'],
#  ['the'],
#  ['hour'],
#  ['of', 'eparation.', '*****', 'And'],
#  ['others'],
#  ['came'],
#  ['also'],
#  ['and'],
#  ['entreated'],
#  ['him.', 'ut'],
#  ['he'],
#  ['answered'],
#  ['them'],
#  ['not.'],
#  ['He'],
#  ['only'],
#  ['bent', 'is'],
#  ['head;'],
#  ['and'],
#  ['those'],
#  ['who'],
#  ['stood'],
#  ['near'],
#  ['saw', 'is'],
#  ['tears'],
#  ['falling'],
#  ['upon'],
#  ['his'],
#  ['breast.', 'And'],
#  ['he'],
#  ['and'],
#  ['the'],
#  ['people'],
#  ['proceeded'],
#  ['towards', 'he'],
#  ['great'],
#  ['square'],
#  ['before'],
#  ['the'],
#  ['temple.', 'And'],
#  ['there'],
#  ['came'],
#  ['out'],
#  ['of'],
#  ['the'],
#  ['sanctuary'],
#  ['a', 'oman'],
#  ['whose'],
#  ['name'],
#  ['was'],
#  ['Almitra.'],
#  ['And'],
#  ['she', 'as'],
#  ['a'],
#  ['seeress.', 'And'],
#  ['he'],
#  ['looked'],
#  ['upon'],
#  ['her'],
#  ['with'],
#  ['exceeding', 'enderness,'],
#  ['for'],
#  ['it'],
#  ['was'],
#  ['she'],
#  ['who'],
#  ['had'],
#  ['first', 'ought'],
#  ['and'],
#  ['believed'],
#  ['in'],
#  ['him'],
#  ['when'],
#  ['he'],
#  ['had', 'een'],
#  ['but'],
#  ['a'],
#  ['day'],
#  ['in'],
#  ['their'],
#  ['city.'],
#  [''],
#  ['hailed'],
#  ['him,'],
#  ['saying:', 'Prophet'],
#  ['of'],
#  ['God,'],
#  ['in'],
#  ['quest'],
#  ['of'],
#  ['the', 'ttermost,'],
#  ['long'],
#  ['have'],
#  ['you'],
#  ['searched'],
#  ['the', 'istances'],
#  ['for'],
#  ['your'],
#  ['ship.', 'And'],
#  ['now'],
#  ['your'],
#  ['ship'],
#  ['has'],
#  ['come,'],
#  ['and'],
#  ['you'],
#  ['must', 'eeds'],
#  ['go.', 'Deep'],
#  ['is'],
#  ['your'],
#  ['longing'],
#  ['for'],
#  ['the'],
#  ['land'],
#  ['of', 'our'],
#  ['memories'],
#  ['and'],
#  ['the'],
#  ['dwelling'],
#  ['place', 'f'],
#  ['your'],
#  ['greater'],
#  ['desires;'],
#  ['and'],
#  ['our'],
#  ['love', 'ould'],
#  ['not'],
#  ['bind'],
#  ['you'],
#  ['nor'],
#  ['our'],
#  ['needs'],
#  ['hold', 'ou.', 'Yet'],
#  ['this'],
#  ['we'],
#  ['ask'],
#  ['ere'],
#  ['you'],
#  ['leave'],
#  ['us,'],
#  ['that', 'ou'],
#  ['speak'],
#  ['to'],
#  ['us'],
#  ['and'],
#  ['give'],
#  ['us'],
#  ['of'],
#  ['your', 'ruth.', 'And'],
#  ['we'],
#  ['will'],
#  ['give'],
#  ['it'],
#  ['unto'],
#  ['our'],
#  ['children,', 'nd'],
#  ['they'],
#  ['unto'],
#  ['their'],
#  ['children,'],
#  ['and'],
#  ['it', 'hall'],
#  ['not'],
#  ['perish.', 'In'],
#  ['your'],
#  ['aloneness'],
#  ['you'],
#  ['have'],
#  ['watched'],
#  ['with', 'ur'],
#  ['days,'],
#  ['and'],
#  ['in'],
#  ['your'],
#  ['wakefulness'],
#  ['you', 'ave'],
#  ['listened'],
#  ['to'],
#  ['the'],
#  ['weeping'],
#  ['and'],
#  ['the', 'aughter'],
#  ['of'],
#  ['our'],
#  ['sleep.', 'Now'],
#  ['therefore'],
#  ['disclose'],
#  ['us'],
#  ['to'],
#  ['ourselves,', 'nd'],
#  ['tell'],
#  ['us'],
#  ['all'],
#  ['that'],
#  ['has'],
#  ['been'],
#  ['shown', 'ou'],
#  ['of'],
#  ['that'],
#  ['which'],
#  ['is'],
#  ['between'],
#  ['birth'],
#  ['and', 'eath.', '*****', 'And'],
#  ['he'],
#  ['answered,', 'People'],
#  ['of'],
#  ['Orphalese,'],
#  ...]

# %% [markdown]
# If you look at the elements of `prophet_line`, you will see that the function returned lists and not strings. Our list is now a list of lists. Flatten the list using list comprehension. Assign this new list to `prophet_flat`.

# %%
prophet_flat = [i for sub in prophet_line for i in sub]

# %%
# def flatten_list(input_list):
#     result = []
#     for item in input_list:
#         if isinstance(item, list):
#             result.extend(flatten_list(item))
#         else:
#             result.append(item)
#     return result

# prophet_flat = flatten_list(prophet_line)
# print(prophet_flat)

# %%
# your code here

# %% [markdown]
# # Challenge 2 - Filtering
#
# When printing out a few words from the book, we see that there are words that we may not want to keep if we choose to analyze the corpus of text. Below is a list of words that we would like to get rid of. Create a function that will return false if it contains a word from the list of words specified and true otherwise.

# %%
def word_filter(x):
    '''
    Input: A string
    Output: True if the word is not in the specified list 
    and False if the word is in the list.
        
    Example:
    word list = ['and', 'the']
    Input: 'and'
    Output: False
    
    Input: 'John'
    Output: True
    '''
    
    word_list = ['and', 'the', 'a', 'an']

    if x.lower() in word_list:
        return False
    else:
        return True
    
    # your code here

# %% [markdown]
# Use the `filter()` function to filter out the words speficied in the `word_filter()` function. Store the filtered list in the variable `prophet_filter`.

# %%
# your code here
prophet_filter = list(filter(word_filter, prophet_flat))
print(prophet_filter)
# Out:
# ['PROPHET', '|Almustafa,', 'chosen', 'eloved,', 'who', 'was', 'dawn', 'unto', 'his', 'own', 'ay,', 'had', 'waited', 'twelve', 'years', 'in', 'city', 'f', 'Orphalese', 'for', 'his', 'ship', 'that', 'was', 'to', 'eturn', 'bear', 'him', 'back', 'to', 'isle', 'of', 'is', 'birth.', 'in', 'twelfth', 'year,', 'on', 'seventh', 'ay', 'of', 'Ielool,', 'month', 'of', 'reaping,', 'he', 'limbed', 'hill', 'without', 'city', 'walls', 'nd', 'looked', 'seaward;', 'he', 'beheld', 'his', 'hip', 'coming', 'with', 'mist.', 'Then', 'gates', 'of', 'his', 'heart', 'were', 'flung', 'pen,', 'his', 'joy', 'flew', 'far', 'over', 'sea.', 'nd', 'he', 'closed', 'his', 'eyes', 'prayed', 'in', 'ilences', 'of', 'his', 'soul.', '*****', 'But', 'as', 'he', 'descended', 'hill,', 'sadness', 'ame', 'upon', 'him,', 'he', 'thought', 'in', 'his', 'eart:', 'How', 'shall', 'I', 'go', 'in', 'peace', 'without', 'orrow?', 'Nay,', 'not', 'without', 'wound', 'in', 'pirit', 'shall', 'I', 'leave', 'this', 'city.', '', 'days', 'of', 'pain', 'I', 'have', 'spent', 'ithin', 'its', 'walls,', 'long', 'were', 'ights', 'of', 'aloneness;', 'who', 'can', 'depart', 'rom', 'his', 'pain', 'his', 'aloneness', 'without', 'egret?', 'Too', 'many', 'fragments', 'of', 'spirit', 'have', 'I', 'cattered', 'in', 'these', 'streets,', 'too', 'many', 're', 'children', 'of', 'my', 'longing', 'that', 'walk', 'aked', 'among', 'these', 'hills,', 'I', 'cannot', 'ithdraw', 'from', 'them', 'without', 'burden', 'n', 'ache.', 'It', 'is', 'not', 'garment', 'I', 'cast', 'off', 'this', 'ay,', 'but', 'skin', 'that', 'I', 'tear', 'with', 'my', 'own', 'ands.', 'Nor', 'is', 'it', 'thought', 'I', 'leave', 'behind', 'me,', 'ut', 'heart', 'made', 'sweet', 'with', 'hunger', 'ith', 'thirst.', '*****', 'Yet', 'I', 'cannot', 'tarry', 'longer.', 'sea', 'that', 'calls', 'all', 'things', 'unto', 'her', 'alls', 'me,', 'I', 'must', 'embark.', 'For', 'to', 'stay,', 'though', 'hours', 'burn', 'in', 'he', 'night,', 'is', 'to', 'freeze', 'crystallize', 'nd', 'be', 'bound', 'in', 'mould.', 'Fain', 'would', 'I', 'take', 'with', 'me', 'all', 'that', 'is', 'ere.', 'But', 'how', 'shall', 'I?', 'voice', 'cannot', 'carry', 'tongue', '', 'lips', 'that', 'gave', 'it', 'wings.', 'Alone', 'ust', 'it', 'seek', 'ether.', 'alone', 'without', 'his', 'nest', 'shall', 'agle', 'fly', 'across', 'sun.', '*****', 'Now', 'when', 'he', 'reached', 'foot', 'of', 'ill,', 'he', 'turned', 'again', 'towards', 'sea,', 'nd', 'he', 'saw', 'his', 'ship', 'approaching', 'arbour,', 'upon', 'her', 'prow', 'mariners,', 'he', 'men', 'of', 'his', 'own', 'land.', 'his', 'soul', 'cried', 'out', 'to', 'them,', 'he', 'aid:', 'Sons', 'of', 'my', 'ancient', 'mother,', 'you', 'riders', 'of', 'he', 'tides,', 'How', 'often', 'have', 'you', 'sailed', 'in', 'my', 'dreams.', 'nd', 'now', 'you', 'come', 'in', 'my', 'awakening,', 'which', 's', 'my', 'deeper', 'dream.', 'Ready', 'am', 'I', 'to', 'go,', 'my', 'eagerness', 'with', 'ails', 'full', 'set', 'awaits', 'wind.', 'Only', 'another', 'breath', 'will', 'I', 'breathe', 'in', 'his', 'still', 'air,', 'only', 'another', 'loving', 'look', 'ast', 'backward,', 'then', 'I', 'shall', 'stand', 'among', 'you,', 'eafarer', 'among', 'seafarers.', '', 'you,', 'ast', 'sea,', 'sleepless', 'mother,', 'Who', 'alone', 'are', 'peace', 'freedom', 'to', 'iver', 'stream,', 'Only', 'another', 'winding', 'will', 'this', 'stream', 'ake,', 'only', 'another', 'murmur', 'in', 'this', 'glade,', 'then', 'shall', 'I', 'come', 'to', 'you,', 'oundless', 'drop', 'to', 'boundless', 'ocean.', '*****', 'as', 'he', 'walked', 'he', 'saw', 'from', 'afar', 'men', 'nd', 'women', 'leaving', 'their', 'fields', 'their', 'ineyards', 'hastening', 'towards', 'city', 'ates.', 'he', 'heard', 'their', 'voices', 'calling', 'his', 'ame,', 'shouting', 'from', 'field', 'to', 'field', 'elling', 'one', 'another', 'of', 'coming', 'of', 'his', 'hip.', 'he', 'said', 'to', 'himself:', 'Shall', 'day', 'of', 'parting', 'be', 'day', 'of', 'athering?', 'shall', 'it', 'be', 'said', 'that', 'my', 'e ...

# %% [markdown]
# # Bonus Challenge
#
# Rewrite the `word_filter` function above to not be case sensitive.

# %%
def word_filter_case(x):
   
    word_list = ['and', 'the', 'a', 'an']

    if x.lower() in word_list:
        return False
    else:
        return True
    
    # your code here

# %% [markdown]
# # Challenge 3 - Reducing
#
# #### Now that we have significantly cleaned up our text corpus, let's use the `reduce()` function to put the words back together into one long string separated by spaces.
#
# We will start by writing a function that takes two strings and concatenates them together with a space between the two strings.

# %%
def concat_space(a, b):
    '''
    Input:Two strings
    Output: A single string separated by a space
        
    Example:
    Input: 'John', 'Smith'
    Output: 'John Smith'
    '''
    return( a + " " + b)
    # your code here

# %% [markdown]
# Use the function above to reduce the text corpus in the list `prophet_filter` into a single string. Assign this new string to the variable `prophet_string`.

# %%
# your code here
prophet_string = reduce(concat_space, prophet_filter)
print(prophet_string)
# Out:
# PROPHET |Almustafa, chosen eloved, who was dawn unto his own ay, had waited twelve years in city f Orphalese for his ship that was to eturn bear him back to isle of is birth. in twelfth year, on seventh ay of Ielool, month of reaping, he limbed hill without city walls nd looked seaward; he beheld his hip coming with mist. Then gates of his heart were flung pen, his joy flew far over sea. nd he closed his eyes prayed in ilences of his soul. ***** But as he descended hill, sadness ame upon him, he thought in his eart: How shall I go in peace without orrow? Nay, not without wound in pirit shall I leave this city.  days of pain I have spent ithin its walls, long were ights of aloneness; who can depart rom his pain his aloneness without egret? Too many fragments of spirit have I cattered in these streets, too many re children of my longing that walk aked among these hills, I cannot ithdraw from them without burden n ache. It is not garment I cast off this ay, but skin that I tear with my own ands. Nor is it thought I leave behind me, ut heart made sweet with hunger ith thirst. ***** Yet I cannot tarry longer. sea that calls all things unto her alls me, I must embark. For to stay, though hours burn in he night, is to freeze crystallize nd be bound in mould. Fain would I take with me all that is ere. But how shall I? voice cannot carry tongue  lips that gave it wings. Alone ust it seek ether. alone without his nest shall agle fly across sun. ***** Now when he reached foot of ill, he turned again towards sea, nd he saw his ship approaching arbour, upon her prow mariners, he men of his own land. his soul cried out to them, he aid: Sons of my ancient mother, you riders of he tides, How often have you sailed in my dreams. nd now you come in my awakening, which s my deeper dream. Ready am I to go, my eagerness with ails full set awaits wind. Only another breath will I breathe in his still air, only another loving look ast backward, then I shall stand among you, eafarer among seafarers.  you, ast sea, sleepless mother, Who alone are peace freedom to iver stream, Only another winding will this stream ake, only another murmur in this glade, then shall I come to you, oundless drop to boundless ocean. ***** as he walked he saw from afar men nd women leaving their fields their ineyards hastening towards city ates. he heard their voices calling his ame, shouting from field to field elling one another of coming of his hip. he said to himself: Shall day of parting be day of athering? shall it be said that my eve was in ruth my dawn? what shall I give unto him who has eft his plough in midfurrow, or to im who has stopped wheel of his inepress?  my heart become ree heavy-laden with fruit that I may ather give unto them? shall my desires flow like ountain that I may fill their cups? Am I harp that hand of mighty ay touch me, or flute that his breath ay pass through me? seeker of silences am I, what reasure have I found in silences that I ay dispense with confidence? If this is my day of harvest, in what ields have I sowed seed, in hat unremembered seasons? If this indeed be hour in which I ift up my lantern, it is not my flame hat shall burn therein. Empty dark shall I raise my lantern, guardian of night shall fill t with oil he shall light it also. ***** These things he said in words. But much n his heart remained unsaid. For  could not speak his deeper ecret. ***** [Illustration: 0020] when he entered into city all he people came to meet him, they ere crying out to him as with one oice. elders of city stood forth nd said: Go not yet away from us. noontide have you been in our wilight, your youth has given us reams to dream. No stranger are you among us, nor  guest, but our son our dearly eloved. Suffer not yet our eyes to hunger for our face. ***** priests priestesses said nto him: Let not waves of sea separate us ow, years you have spent in our idst become memory. You have walked among us spirit,  your shadow has been light pon our faces. Much hav ...
